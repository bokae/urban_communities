# %% [markdown]
# ## Community detection for all metropolitan areas

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import seaborn as sns
import networkx as nx

import scipy
import csv

import matplotlib.cm as cm
import matplotlib.pyplot as plt
import json
import community as community_louvain
from copy import deepcopy
# from modularity_maximization.utils import get_modularity

from itertools import product
import networkx.algorithms.community as nx_comm
from scipy.spatial.distance import pdist, squareform

import math
from time import time

import matplotlib.lines as lines

## %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['time', 'product']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from oct2py import octave
#octave.addpath('/home/ubuntu/GenLouvain/')
#octave.addpath('/home/ubuntu/GenLouvain/private/')
_ = octave.addpath('/home/barcsab/projects/urban_communities/scripts')
_ = octave.addpath('/home/ubuntu/GenLouvain/')
_ = octave.addpath('/home/ubuntu/GenLouvain/private/')

# %% [markdown]
# ### data

# %%
# three networks - data IN
mobility = pd.read_csv("../data/usageousers_city_mobility_CT_networks.rpt.gz") ## basis of position and node importance calculations
follow_hh = pd.read_csv("../data/usageousers_city_follower_CT_HH_networks.rpt.gz")
follow_hh = follow_hh.rename(columns={"tract_home.1": "tract_home_1"})

# census tract name -> cbsacode
cbsacode = pd.read_csv("../data/cbsacode_shortname_tracts.csv",sep=";", index_col=0)
cbsacode['clean_name'] = cbsacode["short_name"].map(lambda s: s.split("/")[0].replace(' ','_').replace('.','').lower())
cbsacode['state'] = cbsacode['geoid'].map(lambda i: i[7:9])
cbsacode['county'] = cbsacode['geoid'].map(lambda i: i[9:12])
cbsacode['tract'] = cbsacode['geoid'].map(lambda i: i[12:18])

# census data
census_1 = pd.read_csv("../data/censusdata_top50_2012.csv")
census_2 = pd.read_csv("../data/censusdata_top50_2017.csv")

# reading geojson data, converting it to geopandas dataframe
tract_geoms = gpd.GeoDataFrame.from_features(
    [json.loads(e.strip('\n')) for e in open('../data/censustract_geoms_top50.geojson').readlines()]
)

# Cartesian coordinate projection of tract centroids
tract_geoms['centroid'] = tract_geoms['geometry'].centroid
tract_center_dict = tract_geoms\
    .set_geometry('centroid',crs={'init':'epsg:4326'})\
    .to_crs({'init':'epsg:3785'})\
    .set_index('full_geoid')['centroid'].map(lambda p: p.coords[0]).to_dict()

counties = gpd.read_file('../data/tl_2012_us_county.shp') # KERDES
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
# function to create tract geoids
def create_geoid(row):
    state = str(int(row["state"])).zfill(2)
    county = str(int(row["county"])).zfill(3)
    tract = str(int(row["tract"])).zfill(6)
    return "14000US" +state+county+tract

census_1['geoid'] = census_1.apply(create_geoid,axis=1)
census_2['geoid'] = census_2.apply(create_geoid,axis=1)

census_1 = census_1.add_suffix('_1')
census_2 = census_2.add_suffix('_2')

# %% [markdown]
# # Functions

# %%
def create_graphs(city, g_type):
    """
    For a given city name, it generates a mobility and follower (home-home) graph.
    
    e.g. g_mob, g_fol_hh = create_graphs("Boston")
    
    It uses the previously loaded `mobility` and `follow_hh` pandas.DataFrames, in which
    the edges are listed for every city.
    
    Parameters:
    -----------
    city : str
        name of the city, see cbsacode dataframe -> clean_name
        
    g_type : str
        either "mob" as mobility or "fol_hh" as follow_hh 
        selects the type of graph to return
        
    Returns:
    --------
    
    g : networkx.Graph
        weighted undirected graph based on city name and g_type (e.g. follow_hh graph of Boston)
        
    """
    # city cbsacode based on name
    city_code = cbsacode[cbsacode.clean_name == city].iloc[0].cbsacode
    
    # select graph type
    if g_type == "mob":
        # filtering large dataframes for the given city code
        mob_df = mobility[(mobility["cbsacode"] == city_code)&(mobility["tract_home"]!=mobility["tract_work"])]

        # create graphs
        # create empty graphs
        g_mob = nx.DiGraph() # mobility graph - weights are counts

        # fill in the networks with data
        mob_df['w_edges'] = list(zip(mob_df.tract_home,mob_df.tract_work,mob_df.cnt))
        g_mob.add_weighted_edges_from(mob_df["w_edges"], weight='cnt')

        # ineffective and slow!
        for e in g_mob.edges():
            r = (e[1],e[0])

            if r in g_mob.edges():
                c1 = g_mob.edges[e]['cnt']
                c2 = g_mob.edges[r]['cnt']

                g_mob.edges[e]['cnt'] = c1 + c2
                g_mob.edges[r]['cnt'] = c1 + c2

        # then let's convert the mobility graph to udirected
        g_mob = g_mob.to_undirected()

        g = g_mob
        
    elif g_type == "fol_hh":            
        # filtering large dataframes for the given city code
        fol_hh_df = follow_hh[(follow_hh["cbsacode"] == city_code)&(follow_hh["tract_home"]!=follow_hh["tract_home_1"])]

        # create graphs
        # create empty graphs
        g_fol_hh = nx.Graph() # follow home-home graph - weights are counts

        # this is an undirected graph already in the dataframe
        fol_hh_df['w_edges'] = list(zip(fol_hh_df.tract_home,fol_hh_df.tract_home_1,fol_hh_df.cnt))
        g_fol_hh.add_weighted_edges_from(fol_hh_df["w_edges"], weight='cnt')
        
        g = g_fol_hh
        
    # TODO --> DONE
    # check data - if all nodes of the graph are in the tract_geom dataframe
    # e.g. in create_graphs()
    # if someone's not there, that is data error, print the tract_id, and leave the node out of the graph G
    # only after this should we calculate the Expert input data    
    while not set(g.nodes).issubset(set(tract_geoms.full_geoid)): # KERDES: ezt hogyan ellenőrizzem le?
        print('DATA ERROR. Node do(es) not have corresponding geodata, so dropped.')
        print('Dropped node(s):')
        nodes_to_drop = set(g.nodes).difference(set(tract_geoms.full_geoid))
        g.remove_nodes_from(nodes_to_drop)
    return g

# %%
def SpaMod(A,D,N,binnumber): # binnumber instead of b = binsize
    """
    Function that calculates the matrix for the clustering 
    based on spatial null model a la Expert.
    
    Parameters:
    -----------
    
    A : scipy.sparse.csr.csr_matrix
        adjacency matrix
    D : numpy.ndarray
        Distance matrix between the nodes
    N : numpy.matrix
        a measure of the importance of a node
        the number of users living(home-location) in the given tract
    binnumber : int
        number of distance bins (used in the estimation of the deterrence function)
    Returns:
    --------
    
    KERDES - ellenorizni
    ModularitySpa : 
    ModularityGN :
    """
    
    tic = time()
    
    print("Beginning of modularity function...");   
    # felesleges?? KERDES -- symmetrised matrix (doesn't change the outcome of community detection (arXiv:0812.1770))
    A = A + A.T ### KERDES KELL-e?? TODO ATGONDOLNI? ILLETVE LE KELL-e osztani 2-vel   / 2     
    b = D.max()/(binnumber-1) # MODIFIED
    
    # deterrence function
    det, detbins = np.histogram(
        D.flatten(),
        range = (0, np.ceil(D.max()/b)*b), # JAVITAS
        weights = np.array(A.todense()).flatten(), 
        bins=int(np.ceil(D.max()/b))
    )
    normadet, _ = np.histogram(
        D.flatten(), 
        range = (0, np.ceil(D.max()/b)*b),
        weights = np.array(N*N.T).flatten(), 
        bins=int(np.ceil(D.max()/b))
    )
    det = det / normadet
    det[np.isnan(det)] = 0
    
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    
    #tic = toc
    
    print("Null modell...")
    
    # copmutation of the randomised correlations (preserving space), spatial
    # null-model
    nullmodelSpa = det[np.digitize(D,detbins,right=True)-1]
    
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    
    #tic = toc
    
    print("Modularity calc...")
    
    # the modularity matrix for the spatial null-model
    ModularitySpa=A-np.multiply(N*N.T, nullmodelSpa*A.sum())/(np.multiply(N*N.T,nullmodelSpa).sum())
    szamlalo = np.multiply(N*N.T, nullmodelSpa*A.sum())
    nevezo = np.multiply(N*N.T,nullmodelSpa).sum()
    
    # the modularity matrix for the GN null-model
    degree = A.sum(axis=0) # JAVITVA np.squeeze(np.asarray(A.sum(axis=0))) # degree or strength of nodes || asarry for further usage
    nullmodelGN = degree.T*degree/degree.sum() # Newman-Girvan null-model
    ModularityGN = A - nullmodelGN
    
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    
    return ModularitySpa, ModularityGN

# %%
# CONSENSUS CLUSTERING
def consen(city, algorithm_type, g_type):
    """
    Function that does the consensus clustering based on the results
    of multiple runs of previous algorithms.
    
    Parameters:
    -----------
    
    city : str
        cityname to runt he consensus clustering for (see cbsacode.clean_name)
    algorithm_type: str
        either "ms" or "mgn" 
        selects the clustering algoritm type: spatail (a la Expert) or ordinary Louvain clustering with Girvan-Newman
    g_type : str
        either "mobility" or "follow_hh"
        selects the type of graph
        
    Returns:
    --------
    
    s_louv : dict
        tract_geoid -> partition label (int)
    """
    
    tic = time()

    print("Reading in necessary data...")
    csv = '../data/consensus_' + city + '_' + algorithm_type + '_' + g_type + '.csv'

    # results of multiple iterations from previous runs
    iters = pd.read_csv(csv)
    iters = iters.set_index('geoid')
    iters['clusts'] = [np.array(l) for l in iters.values.tolist()]

    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    print("Creating all possible node pairs...")
    # create all possible node pairs
    geoid_pairs = list(product(list(iters.index), list(iters.index)))
    consen_df = pd.DataFrame(geoid_pairs, columns=['geoid_1','geoid_2'])

    # remove selfloops
    consen_df = consen_df[consen_df.geoid_1!=consen_df.geoid_2]
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    print("Joining interation results to node pairs...")
    # joining iteration results as lists to both elements of the tract pair
    consen_df = pd.merge(consen_df, iters['clusts'], left_on = 'geoid_1', right_on = 'geoid')
    consen_df = pd.merge(consen_df, iters['clusts'], left_on = 'geoid_2', right_on = 'geoid')
    consen_df = consen_df.rename(columns = {'clusts_x': 'clusts_1', 'clusts_y': 'clusts_2'})
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    print("Counting same partitioning for node pairs...")
    # how many times are the two tracts (geoid_1 and geoid_2) clustered to the same community?
    # --> weights of a graph on which clustering gives the consensus clustering
    print("Calculating difference...")
    diff = np.array(consen_df['clusts_2'].tolist()) == np.array(consen_df['clusts_1'].tolist())
    del consen_df['clusts_1'], consen_df['clusts_2']
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    print("Getting number of zero differences...") # HIBA: KIDOB NODE-OT!!!
    consen_df['w'] = diff.sum(axis=1)
    del diff
    # consen_df = deepcopy(consen_df[consen_df['w']!=0]) ## KERDES: Miért dob ki nodeot? 0326 JAVITAS
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    print("Last Louvain...")
    # graph for consensus clustering
    print("Creating graph...")
    g_cons = nx.Graph() 
    g_cons.add_weighted_edges_from(consen_df[['geoid_1','geoid_2','w']].values, weight='w')
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    del consen_df, iters

    print("Running Louvain...")
    # Louvain community detection 
    s_louv = community_louvain.best_partition(g_cons, weight='w')
    toc = time()
    print("Done.","%.2f" % (toc-tic))
    tic = toc

    return s_louv

# %% [raw]
# # unique lists for city names
# city_l = cbsacode.clean_name.unique()
#
# tract_outdeg_mob = mobility.groupby('tract_home')[['cnt']].sum()
#
# for city in city_l:
#     for g_type in ['mob','fol_hh']:
#         G = create_graphs(city, g_type) # corresponding weighted undirected graph
#
#
#         # TODO --> DONE
#         # index conversion dicts
#         # for i,node_id in enumerate(G.nodes()):
#         # for elem in enumerate(["alma","korte"]):
#         #     print(elem)
#         # geoid -> integer 0-... N-1
#         # az elozo dict megforditottja
#         # int -> geoid
#         index_geoid_dict = dict(list(enumerate(G.nodes)))
#         geoid_index_dict = dict(zip(list(index_geoid_dict.values()), list(index_geoid_dict.keys())))
#
#
#         # Dataprep for Expert algorithm
#         A = nx.adjacency_matrix(G)
#         coords = np.array([tract_center_dict[n] for n in G.nodes()])
#         d = pdist(coords)
#         D = squareform(pdist(coords))
#
#         # importance - number of user home in each tract
#         # TODO we should check if all nodes in the follow_hh graph have an importance!
#         # otherwise, the N... line is going to throw an error
#         if not set(G.nodes).issubset(set(tract_outdeg_mob.reset_index().tract_home)): # test if the node is in any city KERDES : adott városra teszteljem?
#             print('Error. Node(s) without importance value(s) They are dropped.') ## --> DONE
#             missing_nodes = list(set(G.nodes)-set(tract_outdeg_mob.reset_index().tract_home))
#             for node in missing_nodes:
#                 ## KERDES - ezt ki is dobjam??
#                 G.remove_node(node)
#         N = np.matrix([tract_outdeg_mob.loc[k].iloc[0] for k in G.nodes()]).T
#
#
#         # Calculate clusterings for the given graph and write the outcome of runs to csvs
#         S_ms_df = pd.DataFrame()
#         S_mgn_df = pd.DataFrame()
#         for _ in range(10):
#             # TODO Eszter!!!! sometimes it gives an error in the first line
#             # new thing: nout = 3
#             Ms,Mgn = SpaMod(A,D,N,200) ### KERDES what should be the number of bins? 100?
#             S_ms,Q_ms,n_it_ms = octave.iterated_genlouvain(Ms, nout=3)
#             S_ms_df[len(S_ms_df.columns)] = S_ms.T[0]
#             S_mgn,Q_mgn,n_it_mgn = octave.iterated_genlouvain(Mgn, nout=3)
#             S_mgn_df[len(S_mgn_df.columns)] = S_mgn.T[0]
#
#             # TODO itt egy lepesben meg lehet cisnalni mindket algorithm_type-ot!!! --> DONE
#             for (algorithm_type, df) in [('ms',S_ms_df),('mgn',S_mgn_df)]:
#                 df['geoid'] = df.index.map(index_geoid_dict)
#                 # TODO --> DONE  S_df["geoid"] = S_df.index.map(a_masodik_dicted) -- kérdés: ez mit tud, amit az alatta levő sor nem?
#                 #S_df['geoid'] = list(G.nodes()) ## KERDES JO??? - szerintem igen (Eszter)
#                 df = df.set_index('geoid')
#                 csv_name = 'consensus_' + city + '_' + algorithm_type + '_' + g_type + '.csv'
#                 df.to_csv('../data/'+ csv_name)
#                 # TODO --> DONE mindket algorithm type-ra kimenteni a csv-t

# %%
city_l = cbsacode.clean_name.unique()

# %%
from itertools import product

# %%
all_combs = product(city_l, ['mob','fol_hh'], ['ms','mgn'])
city, g_type, algorithm_type = list(all_combs)[0]
city, g_type, algorithm_type
# Out:
# ('new_york', 'mob', 'ms')

# %% [raw]
# # calculating CONSENSUS and putting together the overall dataset and its MODULARITY
# all_consensus_df = pd.DataFrame()
# for city in city_l:
#
#     for g_type in ['mob','fol_hh']:
#
#         for algorithm_type in ['ms','mgn']:
#
#             print (city)
#             print (g_type)
#             print (algorithm_type)
#
#             # storing iteration results, empty dataframe for nodes
#             consensus_df = pd.DataFrame()
#             # TODO atirni az uj fuggveny szerint
#             # de az uj fuggveny meg nem eleg gyors
#             ## eddig ment HIBA, KÉRDÉS
#             S_cons = consen(city, algorithm_type, g_type)
#             consensus_df['S_cons'] = S_cons.values()
#             consensus_df['city'] = city
#             consensus_df['algorithm_type'] = algorithm_type
#             consensus_df['g_type'] = g_type
#             consensus_df['geoid'] = S_cons.keys()
#             consensus_df = consensus_df.set_index('geoid')
#             COUNTY ÉS NMI IDE MAJD
#
#             # calculating modularity
#             G = create_graphs(city, g_type)
#             mod = community_louvain.modularity(S_cons,G)
#             consensus_df['modularity'] = [mod] * len(S_cons.values()) # sorrend jó, ugye? KÉRDÉS
#
#
#             #print('city')
#
#             #csv_name = 'consensus_2_' + city + '_' + algorithm_type + '_' + g_type + '.csv'
#             #consensus_df.to_csv('../data/'+ csv_name)
#             all_consensus_df = pd.concat([all_consensus_df, consensus_df])
#
# all_consensus_df.to_csv('../data/all_cons.csv')

# %% [markdown]
# # Adding data to overall table

# %%
con_df = pd.read_csv('../data/all_cons.csv')

# %%
# number of tracts per city
tract_sum = cbsacode.groupby('clean_name')[['clean_name']].count() 
tract_sum = tract_sum.rename(columns={'clean_name': 'sum_tracts'})

# %%
all_graphs_df = pd.DataFrame(columns=['clean_name','g_type','tracts_in_network'])
all_graphs_df.head()
# Out:
# Empty DataFrame
# Columns: [clean_name, g_type, tracts_in_network]
# Index: []

# %%
# Counting nodes in networks
graph_combs = product(city_l, ['mob','fol_hh'])

for city, g_type in graph_combs:
    G = create_graphs(city, g_type)
    all_graphs_df = all_graphs_df.append({'clean_name': city, 'g_type' : g_type, 'tracts_in_network' : len(G.nodes)}, ignore_index=True)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tract_no_df = pd.merge(all_graphs_df, tract_sum, how = 'left', left_on = 'clean_name', right_index = True)

# %%
# add it to THE dataset
con_df = pd.merge(con_df, tract_no_df, left_on = ['city','g_type'], right_on = ['clean_name','g_type'])
con_df = con_df.drop(columns = ['clean_name'])

# %%
con_df['county'] = con_df['geoid'].map(lambda i: i[9:12])

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score # Adjusted Mutual Information (adjusted against chance)
from sklearn.metrics.cluster import adjusted_rand_score # Adjusted Rand Index

# %%
# 2) Normalized Mutual Information
## How similar is the clustering to the county system? correlation, symmetric function
##  --> the higher the index the more similar the clustering to county system
all_combs = product(city_l, ['mob','fol_hh'], ['ms','mgn'])

nmi_all_df = pd.DataFrame(columns=['city','g_type','algorithm_type','nmi_to_counties','adj_nmi_to_counties','adj_rand_to_counties'])

for city, g_type, algorithm_type in all_combs:
    nmi_df = con_df[(con_df['city'] == city) & (con_df['g_type'] == g_type) & (con_df['algorithm_type'] == algorithm_type)]
    nmi = normalized_mutual_info_score(nmi_df['county'], nmi_df['S_cons'], average_method='arithmetic')
    a_nmi = adjusted_mutual_info_score(nmi_df['county'], nmi_df['S_cons'], average_method='arithmetic')
    a_rand = adjusted_rand_score(nmi_df['county'], nmi_df['S_cons'])
    nmi_all_df = nmi_all_df.append({'city': city, 'g_type' : g_type, 'algorithm_type' : algorithm_type, 'nmi_to_counties' : nmi, 'adj_nmi_to_counties' : a_nmi, 'adj_rand_to_counties' : a_rand}, ignore_index=True)

# %%
# add it to THE dataset
con_df = pd.merge(con_df, nmi_all_df, left_on = ['city','g_type','algorithm_type'], right_on = ['city','g_type','algorithm_type'])

# %%
con_df = con_df.set_index('geoid')

# %%
con_df.to_csv('../data/graph_properties.csv')

# %%
set(nmi_all_df.nmi_to_counties)
# Out:
# {-1.1254392130959919e-15,
#  -3.238180646155405e-16,
#  -7.684783953783232e-17,
#  4.090122788503587e-16,
#  6.082435402832799e-16,
#  1.271962632268071e-15,
#  0.0029747818914699605,
#  0.0035925289204828898,
#  0.014539293969835844,
#  0.015277139290625819,
#  0.04249441360983782,
#  0.05062796993550319,
#  0.05251950863150476,
#  0.053504132866109125,
#  0.05985063851965621,
#  0.06523572627356321,
#  0.06593968062291714,
#  0.06947043720863519,
#  0.07479360262169747,
#  0.08014095616096101,
#  0.08170384785924048,
#  0.08206415151393945,
#  0.08349509250892011,
#  0.08934495033091484,
#  0.10318592045999994,
#  0.12986015179049096,
#  0.14194717041637764,
#  0.1420805424893394,
#  0.15551850663737563,
#  0.15635112514543822,
#  0.15872325544554722,
#  0.16274424198369652,
#  0.16317134188392202,
#  0.16376196256993855,
#  0.16853046481648182,
#  0.1726228501665102,
#  0.1785575932896748,
#  0.18690972730730263,
#  0.1917124987593985,
#  0.19771782737626442,
# ...

# %%
set(nmi_all_df.adj_nmi_to_counties)
# Out:
# {-0.0001982315923401932,
#  -3.181549390098734e-15,
#  -7.01792253630902e-16,
#  -3.238180646155405e-16,
#  4.1566880417684896e-16,
#  1.8977592309691713e-15,
#  2.8421384283592213e-15,
#  0.0004379343520393495,
#  0.005996789164549155,
#  0.011499039724088495,
#  0.030132072142967807,
#  0.036473775323064506,
#  0.04226385964606048,
#  0.048127211185151016,
#  0.05209728557288853,
#  0.05588226965371865,
#  0.06158539111070151,
#  0.06291776899469897,
#  0.06487980278617116,
#  0.06816906046246946,
#  0.07315516630485559,
#  0.07341675752602578,
#  0.07999515439602717,
#  0.08026054780642367,
#  0.09327035783002328,
#  0.1258666087702266,
#  0.1261257164915689,
#  0.13072623605856024,
#  0.13852874724472392,
#  0.14689797677137817,
#  0.14854928618164034,
#  0.14912298608896604,
#  0.15048067817301627,
#  0.15504975740613927,
#  0.15737390898679945,
#  0.16566807741575296,
#  0.1660479318346745,
#  0.17153178072053676,
#  0.17432630790057652,
#  0.18129627774743734,
# ...

# %%
set(nmi_all_df.adj_rand_to_counties)
# Out:
# {-0.022864121540503782,
#  -0.013077651736830214,
#  -0.012192644216133848,
#  -0.00978341966935897,
#  -0.00903143707506121,
#  -0.00011821724669258035,
#  0.0,
#  0.000927233205669476,
#  0.0030076452234419648,
#  0.0031835033375074684,
#  0.004773737383480896,
#  0.009688363191307654,
#  0.011795823514964818,
#  0.017697228371425257,
#  0.017757966428097568,
#  0.023805015206501492,
#  0.02517393914950791,
#  0.029691993624074466,
#  0.03531633451970954,
#  0.03613867479768068,
#  0.03697400342269451,
#  0.04461491803487519,
#  0.047677356503469125,
#  0.05448430541089521,
#  0.06390052345797413,
#  0.0673741151169116,
#  0.06872136688680366,
#  0.07005117797014826,
#  0.07099141187338301,
#  0.0746751693500421,
#  0.07551510440897932,
#  0.0802963598989318,
#  0.08038930522611008,
#  0.08063827428070108,
#  0.0850962573730572,
#  0.08649671754271128,
#  0.08692069504241609,
#  0.09253152169398027,
#  0.0950894597053357,
#  0.09679150825520076,
#  0.09726201660394958,
# ...

# %%
set(nmi_all_df.nmi_to_counties) ## HIBA 0 ALATTI, ES 1 FELETTI ERTEKEK
# Out:
# {-2.375,
#  -1.0,
#  -0.25,
#  0.016327401304773906,
#  0.017270309667959324,
#  0.020398765252502414,
#  0.021933241972437234,
#  0.056655714418564436,
#  0.057411404351582346,
#  0.05987778261246492,
#  0.06918187989316835,
#  0.06948288133753097,
#  0.07340835696442397,
#  0.0836192232753613,
#  0.0893504605272664,
#  0.09000182967453103,
#  0.10189236358430674,
#  0.10448940463547175,
#  0.11703200174448149,
#  0.12568243073247046,
#  0.13207669728298801,
#  0.1377215296301438,
#  0.15460861334178624,
#  0.15669075638907753,
#  0.1587330822716046,
#  0.15876254791208919,
#  0.16266465586759862,
#  0.16430819225819077,
#  0.16458766853772358,
#  0.16918368337058398,
#  0.17033426060072057,
#  0.17106061924132496,
#  0.17262326788629584,
#  0.18248995917869532,
#  0.18878522176831583,
#  0.19506981835096698,
#  0.19861835585316528,
#  0.1990172213648886,
#  0.20148909077052685,
#  0.2070008401097803,
#  0.22197001284634024,
#  0.23265975621656954,
#  0.24163845766333208,
# ...

# %% [markdown]
# ## START FROM HERE
# ### plots from data

# %%
tract_clusters_df = pd.read_csv('../data/graph_properties.csv')
# jövedelem adatot ki kellene TISZTITANI

# %%
# once only
# for regression add unique community label for every community over the 50 cities
# save it to the dataset
tract_clusters_df['S'] = tract_clusters_df['city'] + '_' + tract_clusters_df['S_cons'].astype('str')

tracts_clusters_df = pd.merge(tract_clusters_df, census_1, left_on = 'geoid', right_on = 'geoid_1')
tracts_clusters_df = pd.merge(tracts_clusters_df, census_2, left_on = 'geoid', right_on = 'geoid_2')
tracts_clusters_df = tracts_clusters_df.drop(columns = ['geoid_1', 'geoid_2'])

tracts_clusters_df['income_1'] = tracts_clusters_df['income_1'].replace(-666666666.0, np.nan)
tracts_clusters_df['income_2'] = tracts_clusters_df['income_2'].replace(-666666666.0, np.nan)
tracts_clusters_df['income_growth'] = tracts_clusters_df['income_2'] - tracts_clusters_df['income_1']
tracts_clusters_df['income_growth_p'] = (tracts_clusters_df['income_2'] - tracts_clusters_df['income_1']) / tracts_clusters_df['income_1']
tracts_clusters_df = tracts_clusters_df.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])
#tract_clusters_df.to_csv('../data/graph_properties.csv')

# %%
tract_clusters_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'geoid', 'S_cons',
#        'city', 'algorithm_type', 'g_type', 'modularity', 'tracts_in_network',
#        'sum_tracts', 'county', 'nmi_to_counties', 'adj_nmi_to_counties',
#        'adj_rand_to_counties', 'S'],
#       dtype='object')

# %%
tracts_clusters_df.head()
# Out:
#    Unnamed: 0.1.1               geoid  S_cons      city algorithm_type  \
# 0               0  14000US36005021800       0  new_york             ms
# 1            4603  14000US36005021800       0  new_york            mgn
# 2           13401  14000US36005021800       4  new_york             ms
# 3           17790  14000US36005021800       4  new_york            mgn
# 4               1  14000US36005026500       0  new_york             ms
#
#    g_type  modularity  tracts_in_network  sum_tracts  county  ...  white_2  \
# 0     mob    0.411038               4603        4609       5  ...     1168
# 1     mob    0.516811               4603        4609       5  ...     1168
# 2  fol_hh    0.371920               4389        4609       5  ...     1168
# 3  fol_hh    0.463110               4389        4609       5  ...     1168
# 4     mob    0.411038               4603        4609       5  ...     1285
#
#    white_error_2  black_2 black_error_2  native_2  native_error_2  asian_2  \
# ...

# %%
graphs_df = tract_clusters_df.groupby(['city','algorithm_type','g_type'])[['city','algorithm_type','g_type','modularity','tracts_in_network','sum_tracts','nmi_to_counties','adj_nmi_to_counties','adj_rand_to_counties']].max().reset_index() # LEELLENORIZNI, UGYANAZ-E, MINT AZ NMI DF

# %%
graphs_df.head()
# Out:
#       city algorithm_type  g_type  adj_nmi_to_counties  adj_rand_to_counties  \
# 0  atlanta            mgn  fol_hh             0.521675              0.325522
# 1  atlanta            mgn     mob             0.587757              0.357970
# 2  atlanta             ms  fol_hh             0.126126              0.036139
# 3  atlanta             ms     mob             0.353124              0.157283
# 4   austin            mgn  fol_hh             0.155050              0.104118
#
#    modularity  nmi_to_counties  sum_tracts  tracts_in_network
# 0    0.280535         0.536659         947                940
# 1    0.412011         0.603074         947                947
# 2    0.153237         0.141947         947                940
# 3    0.277414         0.373254         947                947
# 4    0.228105         0.168530         348                345

# %%
hist(graphs_df[graphs_df['algorithm_type'] == 'ms']['adj_nmi_to_counties'], color='green',bins = 50, alpha=0.3, label='ms')
hist(graphs_df[graphs_df['algorithm_type'] == 'mgn']['adj_nmi_to_counties'], color='red',bins = 50, alpha=0.3, label='mgn')
xlabel('Adjusted Mutual Information')
ylabel('No. graphs')
title('Similarity of county and cluster labels per clustering methods')
legend()
grid()

# %%
graphs_ms_mob_df = deepcopy(graphs_df[(graphs_df['algorithm_type'] == 'ms') & (graphs_df['g_type'] == 'mob')])
graphs_mgn_mob_df = deepcopy(graphs_df[(graphs_df['algorithm_type'] == 'mgn') & (graphs_df['g_type'] == 'mob')])
graphs_ms_fol_hh_df = deepcopy(graphs_df[(graphs_df['algorithm_type'] == 'ms') & (graphs_df['g_type'] == 'fol_hh')])
graphs_mgn_fol_hh_df = deepcopy(graphs_df[(graphs_df['algorithm_type'] == 'mgn') & (graphs_df['g_type'] == 'fol_hh')])

# %%
hist(graphs_ms_mob_df['adj_nmi_to_counties'], color='green',bins = 50, alpha=0.3, label='ms')
hist(graphs_mgn_mob_df['adj_nmi_to_counties'], color='red',bins = 50, alpha=0.3, label='mgn')
xlabel('Adjusted Mutual Information')
ylabel('No. graphs')
title('Similarity of county and cluster labels per clustering methods in mobility graphs')
legend()
grid()

# %%
hist(graphs_ms_fol_hh_df['adj_nmi_to_counties'], color='green',bins = 50, alpha=0.3, label='ms')
hist(graphs_mgn_fol_hh_df['adj_nmi_to_counties'], color='red',bins = 50, alpha=0.3, label='mgn')
xlabel('Adjusted Mutual Information')
ylabel('No. graphs')
title('Similarity of county and cluster labels per clustering methods in follower home-home graphs')
legend()
grid()

# %%
fig, ax = plt.subplots()
plt.title('Cluster similarity to counties in mobility graphs depending on clustering algorithms')
plt.xlabel('ms')
plt.ylabel('mgn')

ax.scatter(x = graphs_ms_mob_df.adj_nmi_to_counties, y = graphs_mgn_mob_df.adj_nmi_to_counties, c='DarkBlue', alpha=0.3)
line = lines.Line2D([0, 0.8], [0, 0.8], color='red', alpha=0.5)
ax.add_line(line)
plt.show()

# %% [markdown]
# # Inequality calculations

# %% [markdown]
# ### TISZTÍTOTT ADATOT KELLENE HASZNALNI!!!!! FELADAT? HIBA, incomeban nem lehet 0 CT_02-ből??????

# %% [markdown]
# rey_Regional_convergence_inequality_and_space_2005_Review

# %%
tracts_df = pd.merge(tract_clusters_df, census_1, left_on = 'geoid', right_on = 'geoid_1')
tracts_df = pd.merge(tracts_df, census_2, left_on = 'geoid', right_on = 'geoid_2')
tracts_df = tracts_df.drop(columns = ['geoid_1', 'geoid_2'])
tracts_df['ones'] = 1 # for counting tract numbers in groups with sum()

# %%
# handling missing values which were indicated as '-666666666.0'
# TISZTITOTT ADAT KELLENE

tracts_df['income_1'] = tracts_df['income_1'].replace(-666666666.0, np.nan)
tracts_df['income_2'] = tracts_df['income_2'].replace(-666666666.0, np.nan)

# %%
# ELLENORIZNI, HOGY A TRACTS_DF-BEN CSAK OLYAN TRACT VAN, AMI HALOZATBAN IS VAN, MERT ERRE ALAPSZIK A KOVI SZAMITAS, UGYE??? Talan..

# %%
group_df = deepcopy(tracts_df[['geoid', 'S_cons', 'city', 'county', 'algorithm_type', 'g_type', 'income_1', 'income_2', 
                               'population_1', 'population_2', 'white_1', 'white_2', 'black_1','black_2', 'native_1', 'native_2',
                               'asian_1', 'asian_2', 'education_bachelor_1', 'education_bachelor_2', 'ones']])

# %%
city_df = group_df.groupby(['city', 'algorithm_type', 'g_type']).sum().reset_index()
city_df = city_df.drop(columns = ['S_cons', 'county'])
city_df = city_df.rename(columns = {'income_1' : 'income_1_city_sum', 'income_2' : 'income_2_city_sum',
                                    'population_1' : 'population_1_city_sum', 'population_2' : 'population_2_city_sum',
                                    'white_1' : 'white_1_city_sum', 'white_2' : 'white_2_city_sum',
                                     'black_1' : 'black_1_city_sum', 'black_2' : 'black_2_city_sum',
                                    'native_1' : 'native_1_city_sum', 'native_2': 'native_2_city_sum',
                                    'asian_1' : 'asian_1_city_sum', 'asian_2' : 'asian_2_city_sum',
                                    'education_bachelor_1' : 'educ_ba_1_city_sum', 'education_bachelor_2' : 'educ_ba_2_city_sum',                                    
                                    'ones' : 'tracts_in_city'})

# %%
clust_df = group_df.groupby(['city', 'algorithm_type', 'g_type', 'S_cons']).sum().reset_index()
clust_df = clust_df.drop(columns = ['county'])
clust_df = clust_df.rename(columns = {'income_1' : 'income_1_clust_sum', 'income_2' : 'income_2_clust_sum', 
                                      'population_1' : 'population_1_clust_sum', 'population_2' : 'population_2_clust_sum',
                                      'white_1' : 'white_1_clust_sum', 'white_2' : 'white_2_clust_sum',
                                      'black_1' : 'black_1_clust_sum', 'black_2' : 'black_2_clust_sum',
                                      'native_1' : 'native_1_clust_sum', 'native_2': 'native_2_clust_sum',
                                      'asian_1' : 'asian_1_clust_sum', 'asian_2' : 'asian_2_clust_sum',
                                      'education_bachelor_1' : 'educ_ba_1_clust_sum', 'education_bachelor_2' : 'educ_ba_2_clust_sum',
                                      'ones' : 'tracts_in_clust'})
clust_df = pd.merge(clust_df, city_df, on = ['city', 'algorithm_type', 'g_type'])

# %%
county_df = group_df.groupby(['city', 'algorithm_type', 'g_type', 'county']).sum().reset_index()
county_df = county_df.drop(columns = ['S_cons'])
county_df = county_df.rename(columns = {'income_1' : 'income_1_county_sum', 'income_2' : 'income_2_county_sum', 
                                        'population_1' : 'population_1_county_sum', 'population_2' : 'population_2_county_sum',
                                        'white_1' : 'white_1_county_sum', 'white_2' : 'white_2_county_sum',
                                        'black_1' : 'black_1_county_sum', 'black_2' : 'black_2_county_sum',
                                        'native_1' : 'native_1_county_sum', 'native_2': 'native_2_county_sum',
                                        'asian_1' : 'asian_1_county_sum', 'asian_2' : 'asian_2_county_sum',
                                        'education_bachelor_1' : 'educ_ba_1_county_sum', 'education_bachelor_2' : 'educ_ba_2_county_sum',
                                        'ones' : 'tracts_in_county'})
county_df = pd.merge(county_df, city_df, on = ['city', 'algorithm_type', 'g_type'])

# %% [markdown]
# BEGINING of income calculations
# ami ebben hiba, azt a következőkeben is javítani kell, azaz a nem incomera végeztem számításokban is

# %%
# T = TB(between) + TW(within)  CALCULATIONS FROM rey_Regional_convergence_inequality_and_space_2005_Review

# 1) FOR CLUSTER AS GROUPS for income_1 and income_2 simultaneously

# 1.1
clust_df['income_1_s_g'] = clust_df['income_1_clust_sum'] / clust_df['income_1_city_sum']
clust_df['income_2_s_g'] = clust_df['income_2_clust_sum'] / clust_df['income_2_city_sum']

# TB before summing up for all groups
# KERDES: TERMESZETES LOGARITMUS KELL? Zárójelezés jó?
clust_df['income_1_TB_group_share'] = clust_df['income_1_s_g'] * ((clust_df['tracts_in_city']/(clust_df['tracts_in_clust'] * clust_df['income_1_s_g'])).map(lambda x : math.log(x)))
clust_df['income_2_TB_group_share'] = clust_df['income_2_s_g'] * ((clust_df['tracts_in_city']/(clust_df['tracts_in_clust'] * clust_df['income_2_s_g'])).map(lambda x : math.log(x)))

group_df = pd.merge(group_df, clust_df, on = ['S_cons', 'city', 'algorithm_type', 'g_type']) # on clusters
# KERDES: A MERGE MIERT KELL KULON CELLÁBAN FUSSON? MIERT NEM MERGELHETEM EZT A CELLÁT A KÖVETKEZŐVEL??

# %%
# 1.2
group_df['income_1_s_i_g'] = group_df['income_1'] / group_df['income_1_clust_sum']
group_df['income_2_s_i_g'] = group_df['income_2'] / group_df['income_2_clust_sum']

group_df['income_1_A'] = group_df['income_1_s_i_g'] * ((group_df['tracts_in_clust'] * group_df['income_1_s_i_g']).map(lambda x : math.log(x)))
group_df['income_2_A'] = group_df['income_2_s_i_g'] * ((group_df['tracts_in_clust'] * group_df['income_2_s_i_g']).map(lambda x : math.log(x)))

# summing up A-s --> group by "group" - clusters here
clust_aux_df = group_df.groupby(['S_cons', 'city', 'algorithm_type', 'g_type'])[['city', 'algorithm_type', 'g_type', 'income_1_A', 'income_2_A']].sum().reset_index()
# KERDES: a masodik zarojelbol miert kell kivennem az S_cons-t??
clust_aux_df = clust_aux_df.rename(columns = {'income_1_A' : 'income_1_A_sum', 'income_2_A' : 'income_2_A_sum'})

clust_df = pd.merge(clust_df, clust_aux_df,  on = ['S_cons', 'city', 'algorithm_type', 'g_type'])  # on clusters

# %%
# 1.3
clust_df['income_1_TW_group_share'] = clust_df['income_1_s_g'] * clust_df['income_1_A_sum']
clust_df['income_2_TW_group_share'] = clust_df['income_2_s_g'] * clust_df['income_2_A_sum']

# summing up the groups to city level
T_clust_df = clust_df.groupby(['city', 'algorithm_type', 'g_type']).sum().reset_index()[['city', 'algorithm_type', 'g_type', 'income_1_clust_sum', 'income_2_clust_sum', 'income_1_TB_group_share', 'income_1_TW_group_share','income_2_TB_group_share', 'income_2_TW_group_share']]
T_clust_df = T_clust_df.rename(columns = {'income_1_clust_sum' : 'income_1_city_sum', 'income_2_clust_sum' : 'income_2_city_sum', 'income_1_TB_group_share' : 'income_1_TB', 'income_1_TW_group_share' : 'income_1_TW', 'income_2_TB_group_share' : 'income_2_TB', 'income_2_TW_group_share' : 'income_2_TW'})

# %%
T_clust_df['income_growth_p'] = (T_clust_df['income_2_city_sum'] - T_clust_df['income_1_city_sum']) / T_clust_df['income_1_city_sum']
T_clust_df['income_growth'] = T_clust_df['income_2_city_sum'] - T_clust_df['income_1_city_sum']

T_clust_df['income_1_T'] = T_clust_df['income_1_TB'] + T_clust_df['income_1_TW']
T_clust_df['income_1_TB_share'] = T_clust_df['income_1_TB'] / T_clust_df['income_1_T']
T_clust_df['income_1_TW_share'] = T_clust_df['income_1_TW'] / T_clust_df['income_1_T']

T_clust_df['income_2_T'] = T_clust_df['income_2_TB'] + T_clust_df['income_2_TW']
T_clust_df['income_2_TB_share'] = T_clust_df['income_2_TB'] / T_clust_df['income_2_T']
T_clust_df['income_2_TW_share'] = T_clust_df['income_2_TW'] / T_clust_df['income_2_T']

# %% [markdown]
# END of income calculations

# %% [markdown]
# Begining of race calculations - whites

# %%
# 1.1
clust_df['white_1_s_g'] = clust_df['white_1_clust_sum'] / clust_df['white_1_city_sum']
clust_df['white_2_s_g'] = clust_df['white_2_clust_sum'] / clust_df['white_2_city_sum']

clust_df['white_1_TB_group_share'] = clust_df['white_1_s_g'] * ((clust_df['tracts_in_city']/(clust_df['tracts_in_clust'] * clust_df['white_1_s_g'])).map(lambda x : math.log(x)))
clust_df['white_2_TB_group_share'] = clust_df['white_2_s_g'] * ((clust_df['tracts_in_city']/(clust_df['tracts_in_clust'] * clust_df['white_2_s_g'])).map(lambda x : math.log(x)))

group_df = pd.merge(group_df, clust_df[['S_cons', 'city', 'algorithm_type', 'g_type', 'white_1_s_g', 'white_2_s_g', 'white_1_TB_group_share', 'white_2_TB_group_share']], on = ['S_cons', 'city', 'algorithm_type', 'g_type']) # on clusters

# %%
# 1.2
group_df['white_1_s_i_g'] = group_df['white_1'] / group_df['white_1_clust_sum']
group_df['white_2_s_i_g'] = group_df['white_2'] / group_df['white_2_clust_sum']

group_df['white_1_A'] = group_df['white_1_s_i_g'] * ((group_df['tracts_in_clust'] * group_df['white_1_s_i_g']).map(lambda x : np.nan if x == 0 else math.log(x))) # KERDES 0 kezelese jo igy??
group_df['white_2_A'] = group_df['white_2_s_i_g'] * ((group_df['tracts_in_clust'] * group_df['white_2_s_i_g']).map(lambda x : np.nan if x == 0 else math.log(x))) # KERDES 0 kezelese jo igy??  

# summing up A-s --> group by "group" - clusters here
clust_aux_df = group_df.groupby(['S_cons', 'city', 'algorithm_type', 'g_type'])[['city', 'algorithm_type', 'g_type', 'white_1_A', 'white_2_A']].sum().reset_index()
clust_aux_df = clust_aux_df.rename(columns = {'white_1_A' : 'white_1_A_sum', 'white_2_A' : 'white_2_A_sum'})

clust_df = pd.merge(clust_df, clust_aux_df,  on = ['S_cons', 'city', 'algorithm_type', 'g_type'])  # on clusters

# %%
# 1.3
clust_df['white_1_TW_group_share'] = clust_df['white_1_s_g'] * clust_df['white_1_A_sum']
clust_df['white_2_TW_group_share'] = clust_df['white_2_s_g'] * clust_df['white_2_A_sum']

# summing up the groups to city level
T_clust_white_df = clust_df.groupby(['city', 'algorithm_type', 'g_type']).sum().reset_index()[['city', 'algorithm_type', 'g_type', 'white_1_clust_sum', 'white_2_clust_sum', 'white_1_TB_group_share', 'white_1_TW_group_share','white_2_TB_group_share', 'white_2_TW_group_share']]
T_clust_white_df = T_clust_white_df.rename(columns = {'white_1_clust_sum' : 'white_1_city_sum', 'white_2_clust_sum' : 'white_2_city_sum', 'white_1_TB_group_share' : 'white_1_TB', 'white_1_TW_group_share' : 'white_1_TW', 'white_2_TB_group_share' : 'white_2_TB', 'white_2_TW_group_share' : 'white_2_TW'})

# %%
T_clust_white_df['white_growth_p'] = (T_clust_white_df['white_2_city_sum'] - T_clust_white_df['white_1_city_sum']) / T_clust_white_df['white_1_city_sum']

T_clust_white_df['white_1_T'] = T_clust_white_df['white_1_TB'] + T_clust_white_df['white_1_TW']
T_clust_white_df['white_1_TB_share'] = T_clust_white_df['white_1_TB'] / T_clust_white_df['white_1_T']
T_clust_white_df['white_1_TW_share'] = T_clust_white_df['white_1_TW'] / T_clust_white_df['white_1_T']

T_clust_white_df['white_2_T'] = T_clust_white_df['white_2_TB'] + T_clust_white_df['white_2_TW']
T_clust_white_df['white_2_TB_share'] = T_clust_white_df['white_2_TB'] / T_clust_white_df['white_2_T']
T_clust_white_df['white_2_TW_share'] = T_clust_white_df['white_2_TW'] / T_clust_white_df['white_2_T']

# add to T_clust_df in which income calculations are stored
T_clust_df = pd.merge(T_clust_df, T_clust_white_df, on = ['city', 'algorithm_type', 'g_type'])

# %% [markdown]
# End of calculations for whites

# %% [markdown]
# # Plots

# %%
from numpy.polynomial.polynomial import polyfit
import matplotlib.pyplot as plt

df = deepcopy(T_clust_df[(T_clust_df['algorithm_type'] == 'mgn') & (T_clust_df['g_type'] == 'fol_hh')])# & (T_clust_df['city'].isin(['boston','providence','hartford','new_york','philadelphia','baltimore','washington','richmond','virginia_beach']))]) ## HHIIIBBAAA SZURT ADATNAL KI KELL VENNI

# Sample data
x = df['income_1_TB_share']
y = df['income_growth_p']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and inequality in metropolitans', fontsize=17)
plt.xlabel('Income inequality from between groups (%)', fontsize=14)
plt.ylabel('Income growth in (%)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.show()

# %%
x = df['income_1_TW_share']
y = df['income_growth_p']

# Fit with polyfit
b, m = polyfit(x, y, 1)


fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and inequality in metropolitans', fontsize=17)
plt.xlabel('Income inequality from within groups (%)', fontsize=14)
plt.ylabel('Income growth in (%)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.show()

# %%
x = df['income_1_TB_share']
y = df['income_growth']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and inequality in metropolitans', fontsize=17)
plt.xlabel('Income inequality from between groups (%)', fontsize=14)
plt.ylabel('Income growth (dollars)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.show()

# %%
x = df['income_1_TW_share']
y = df['income_growth']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and inequality in metropolitans', fontsize=17)
plt.xlabel('Income inequality from within groups (%)', fontsize=14)
plt.ylabel('Income growth (dollars)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.show()

# %% [raw]
# # 2) FOR COUNTIES AS GROUPS for income_1 and income_2 simultaneously
#
# calculations as above county in place of clusters
#
# KERDES: SZUKSEGES?

# %% [markdown]
# END OF T PLOTS

# %% [markdown]
# ## clusters showing racial segregation AND income growth

# %%
clust_df['white_p'] = clust_df['white_1_clust_sum'] / clust_df['population_1_clust_sum']

clust_df['income_growth'] = clust_df['income_1_clust_sum'] - clust_df['income_2_clust_sum']
clust_df['income_growth_p'] = (clust_df['income_1_clust_sum'] - clust_df['income_2_clust_sum']) / clust_df['income_1_clust_sum']

# %%
x = clust_df['white_p']
y = clust_df['income_growth_p']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and white % in clusters', fontsize=17)
plt.xlabel('White proportion of cluster population', fontsize=14)
plt.ylabel('Income growth (%)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.show()

# %%
x = clust_df['white_p']
y = clust_df['income_growth']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and white % in clusters', fontsize=17)
plt.xlabel('White proportion of cluster population', fontsize=14)
plt.ylabel('Income growth (dollars)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
#plt.yscale('log')
#plt.xscale('log')
plt.show()

# %%
# diference from white percentage of population from overall city white percentage
clust_df['white_p_dif'] = clust_df['white_p'] - (clust_df['white_1_city_sum'] - clust_df['population_1_city_sum'])

# %%
x = clust_df['white_p_dif']
y = clust_df['income_growth_p']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and white surplus in clusters', fontsize=17)
plt.xlabel('White proportion difference from cluster average', fontsize=14)
plt.ylabel('Income growth (%)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
#plt.yscale('log')
#plt.xscale('log')
plt.show()

# %%
x = clust_df['white_p_dif']
y = clust_df['income_growth']

# Fit with polyfit
b, m = polyfit(x, y, 1)

fig, ax = plt.subplots(figsize=(8,6))
plt.title('Income growth and white surplus in clusters', fontsize=17)
plt.xlabel('White proportion difference from cluster average', fontsize=14)
plt.ylabel('Income growth (dollars)', fontsize=14)

plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
#plt.yscale('log')
#plt.ylim(-1000000,100000)
#plt.xscale('log')
plt.show()

# %% [markdown]
# # Community quality

# %% [markdown]
# On Measuring the Quality of a Network Community Structure

# %% [markdown]
# ### Community quality calculations
# - MEASURE (var_name) Large/Small for a good_community_has
# - Intra-edges - (in) L
# - Contraction - (ctr) L = 2*in/number_of_nodes_in_community
# - Inter-edges (out) S
# - Expansion - (expan) S = out/number_of_nodes_in_community
# - Conductance - (cduc) S = out/(2*in + out)

# %%
# creating adding cluster labels to edgelists

mob_mgn_tracts_df = deepcopy(tracts_df[(tracts_df['g_type'] == 'mob') & (tracts_df['algorithm_type'] == 'mgn')])
mob_ms_tracts_df = deepcopy(tracts_df[(tracts_df['g_type'] == 'mob') & (tracts_df['algorithm_type'] == 'ms')])
fol_hh_mgn_tracts_df = deepcopy(tracts_df[(tracts_df['g_type'] == 'fol_hh') & (tracts_df['algorithm_type'] == 'mgn')])
fol_hh_ms_tracts_df = deepcopy(tracts_df[(tracts_df['g_type'] == 'fol_hh') & (tracts_df['algorithm_type'] == 'ms')])

mob_mgn_df = pd.merge(mobility[['tract_home', 'tract_work', 'cnt']], mob_mgn_tracts_df[['geoid', 'S_cons', 'city']], left_on = 'tract_home', right_on = 'geoid')
mob_mgn_df = mob_mgn_df.rename(columns = {'S_cons' : 'S_home'})
mob_mgn_df = pd.merge(mob_mgn_df[['tract_home', 'tract_work', 'cnt', 'S_home', 'city']], mob_mgn_tracts_df[['geoid', 'S_cons', 'tracts_in_network']], left_on = 'tract_work', right_on = 'geoid')
mob_mgn_df = mob_mgn_df.rename(columns = {'S_cons' : 'S_work'})
mob_mgn_df = mob_mgn_df.drop(columns = ['geoid'])

mob_ms_df = pd.merge(mobility[['tract_home', 'tract_work', 'cnt']], mob_ms_tracts_df[['geoid', 'S_cons', 'city']], left_on = 'tract_home', right_on = 'geoid')
mob_ms_df = mob_ms_df.rename(columns = {'S_cons' : 'S_home'})
mob_ms_df = pd.merge(mob_ms_df[['tract_home', 'tract_work', 'cnt', 'S_home', 'city']], mob_ms_tracts_df[['geoid', 'S_cons', 'tracts_in_network']], left_on = 'tract_work', right_on = 'geoid')
mob_ms_df = mob_ms_df.rename(columns = {'S_cons' : 'S_work'})
mob_ms_df = mob_ms_df.drop(columns = ['geoid'])

fol_hh_ms_df = pd.merge(follow_hh[['tract_home', 'tract_home_1', 'cnt']], fol_hh_ms_tracts_df[['geoid', 'S_cons', 'city']], left_on = 'tract_home', right_on = 'geoid')
fol_hh_ms_df = fol_hh_ms_df.rename(columns = {'S_cons' : 'S_home'})
fol_hh_ms_df = pd.merge(fol_hh_ms_df[['tract_home', 'tract_home_1', 'cnt', 'S_home', 'city']], fol_hh_ms_tracts_df[['geoid', 'S_cons', 'tracts_in_network']], left_on = 'tract_home_1', right_on = 'geoid')
fol_hh_ms_df = fol_hh_ms_df.rename(columns = {'S_cons' : 'S_home_1'})
fol_hh_ms_df = fol_hh_ms_df.drop(columns = ['geoid'])

fol_hh_mgn_df = pd.merge(follow_hh[['tract_home', 'tract_home_1', 'cnt']], fol_hh_mgn_tracts_df[['geoid', 'S_cons', 'city']], left_on = 'tract_home', right_on = 'geoid')
fol_hh_mgn_df = fol_hh_mgn_df.rename(columns = {'S_cons' : 'S_home'})
fol_hh_mgn_df = pd.merge(fol_hh_mgn_df[['tract_home', 'tract_home_1', 'cnt', 'S_home', 'city']], fol_hh_mgn_tracts_df[['geoid', 'S_cons', 'tracts_in_network']], left_on = 'tract_home_1', right_on = 'geoid')
fol_hh_mgn_df = fol_hh_mgn_df.rename(columns = {'S_cons' : 'S_home_1'})
fol_hh_mgn_df = fol_hh_mgn_df.drop(columns = ['geoid'])

# %%
# counting edges within(in) and between(out) communities
# edges are only listed once (ex: A-B is in set but is not the same as B-A, these should be added up)

# %%
def same_clust(row):
    if row['S_work'] == row['S_home']:
        return row['cnt']
    else:
        return 0
    
def dif_clust(row):
    if row['S_work'] == row['S_home']:
        return 0
    else:
        return row['cnt']
    
def same_clust_2(row):
    if row['S_home'] == row['S_home_1']:
        return row['cnt']
    else:
        return 0
    
def dif_clust_2(row):
    if row['S_home'] == row['S_home_1']:
        return 0
    else:
        return row['cnt']

# %%
mob_mgn_df = mob_mgn_df.groupby(['city','S_work','S_home']).sum().reset_index()
mob_mgn_df['in'] = mob_mgn_df.apply(same_clust, axis=1)
mob_mgn_df['out'] = mob_mgn_df.apply(dif_clust, axis=1)

mob_mgn_S_df = deepcopy(clust_df[(clust_df['algorithm_type'] == 'mgn') & (clust_df['g_type'] == 'mob')].groupby(['city','S_cons'])).sum().reset_index()[['city','S_cons']] # just to make sure that every cluster is in the list
mob_mgn_S_df = pd.merge(mob_mgn_S_df, mob_mgn_df.groupby(['city','S_work']).sum().reset_index()[['city', 'S_work','out','in', 'tracts_in_network']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_work'])
mob_mgn_S_df = pd.merge(mob_mgn_S_df, mob_mgn_df.groupby(['city','S_home']).sum().reset_index()[['city', 'S_home','out']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_home'])
mob_mgn_S_df['out'] = mob_mgn_S_df['out_x'] + mob_mgn_S_df['out_y']
mob_mgn_S_df = mob_mgn_S_df.drop(columns = ['S_work', 'S_home','out_x','out_y'])



mob_ms_df = mob_ms_df.groupby(['city','S_work','S_home']).sum().reset_index()
mob_ms_df['in'] = mob_ms_df.apply(same_clust, axis=1)
mob_ms_df['out'] = mob_ms_df.apply(dif_clust, axis=1)

mob_ms_S_df = deepcopy(clust_df[(clust_df['algorithm_type'] == 'ms') & (clust_df['g_type'] == 'mob')].groupby(['city','S_cons'])).sum().reset_index()[['city','S_cons']] # just to make sure that every cluster is in the list
mob_ms_S_df = pd.merge(mob_ms_S_df, mob_ms_df.groupby(['city','S_work']).sum().reset_index()[['city', 'S_work','out','in', 'tracts_in_network']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_work'])
mob_ms_S_df = pd.merge(mob_ms_S_df, mob_ms_df.groupby(['city','S_home']).sum().reset_index()[['city', 'S_home','out']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_home'])
mob_ms_S_df['out'] = mob_ms_S_df['out_x'] + mob_ms_S_df['out_y']
mob_ms_S_df = mob_ms_S_df.drop(columns = ['S_work', 'S_home','out_x','out_y'])



fol_hh_mgn_df = fol_hh_mgn_df.groupby(['city','S_home','S_home_1']).sum().reset_index()
fol_hh_mgn_df['in'] = fol_hh_mgn_df.apply(same_clust_2, axis=1)
fol_hh_mgn_df['out'] = fol_hh_mgn_df.apply(dif_clust_2, axis=1)

fol_hh_mgn_S_df = deepcopy(clust_df[(clust_df['algorithm_type'] == 'mgn') & (clust_df['g_type'] == 'fol_hh')].groupby(['city','S_cons'])).sum().reset_index()[['city','S_cons']] # just to make sure that every cluster is in the list
fol_hh_mgn_S_df = pd.merge(fol_hh_mgn_S_df, fol_hh_mgn_df.groupby(['city','S_home']).sum().reset_index()[['city', 'S_home','out','in', 'tracts_in_network']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_home'])
fol_hh_mgn_S_df = pd.merge(fol_hh_mgn_S_df, fol_hh_mgn_df.groupby(['city','S_home_1']).sum().reset_index()[['city', 'S_home_1','out']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_home_1'])
fol_hh_mgn_S_df['out'] = fol_hh_mgn_S_df['out_x'] + fol_hh_mgn_S_df['out_y']
fol_hh_mgn_S_df = fol_hh_mgn_S_df.drop(columns = ['S_home', 'S_home_1','out_x','out_y'])



fol_hh_ms_df = fol_hh_ms_df.groupby(['city','S_home','S_home_1']).sum().reset_index()
fol_hh_ms_df['in'] = fol_hh_ms_df.apply(same_clust_2, axis=1)
fol_hh_ms_df['out'] = fol_hh_ms_df.apply(dif_clust_2, axis=1)

fol_hh_ms_S_df = deepcopy(clust_df[(clust_df['algorithm_type'] == 'ms') & (clust_df['g_type'] == 'fol_hh')].groupby(['city','S_cons'])).sum().reset_index()[['city','S_cons']] # just to make sure that every cluster is in the list
fol_hh_ms_S_df = pd.merge(fol_hh_ms_S_df, fol_hh_ms_df.groupby(['city','S_home']).sum().reset_index()[['city', 'S_home','out','in', 'tracts_in_network']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_home'])
fol_hh_ms_S_df = pd.merge(fol_hh_ms_S_df, fol_hh_ms_df.groupby(['city','S_home_1']).sum().reset_index()[['city', 'S_home_1','out']], left_on = ['city', 'S_cons'], right_on = ['city', 'S_home_1'])
fol_hh_ms_S_df['out'] = fol_hh_ms_S_df['out_x'] + fol_hh_ms_S_df['out_y']
fol_hh_ms_S_df = fol_hh_ms_S_df.drop(columns = ['S_home', 'S_home_1','out_x','out_y'])

# %%
mob_mgn_S_df['ctr'] = 2 * mob_mgn_S_df['in'] / mob_mgn_S_df['tracts_in_network']
mob_ms_S_df['ctr'] = 2 * mob_ms_S_df['in'] / mob_ms_S_df['tracts_in_network']
fol_hh_mgn_S_df['ctr'] = 2 * fol_hh_mgn_S_df['in'] / fol_hh_mgn_S_df['tracts_in_network']
fol_hh_ms_S_df['ctr'] = 2 * fol_hh_ms_S_df['in'] / fol_hh_ms_S_df['tracts_in_network']

mob_mgn_S_df['expan'] = mob_mgn_S_df['out'] / mob_mgn_S_df['tracts_in_network']
mob_ms_S_df['expan'] = mob_ms_S_df['out'] / mob_ms_S_df['tracts_in_network']
fol_hh_mgn_S_df['expan'] = fol_hh_mgn_S_df['out'] / fol_hh_mgn_S_df['tracts_in_network']
fol_hh_ms_S_df['expan'] = fol_hh_ms_S_df['out'] / fol_hh_ms_S_df['tracts_in_network']

mob_mgn_S_df['cduc'] = mob_mgn_S_df['out'] / (2 * mob_mgn_S_df['in'] + mob_mgn_S_df['out'])
mob_ms_S_df['cduc'] = mob_ms_S_df['out'] / (2 * mob_ms_S_df['in'] + mob_ms_S_df['out'])
fol_hh_mgn_S_df['cduc'] = fol_hh_mgn_S_df['out'] / (2 * fol_hh_mgn_S_df['in'] + fol_hh_mgn_S_df['out'])
fol_hh_ms_S_df['cduc'] = fol_hh_ms_S_df['out'] / (2 * fol_hh_ms_S_df['in'] + fol_hh_ms_S_df['out'])

# %% [markdown]
# END of Community quality calculations

# %% [markdown]
# #### Hipothesis: Communities are convergence clubs and spatial communities are better convergence clubs than Girwan-Newman communities.

# %% [markdown]
# - Sigma convergence declines with time within communities
# - Standard error of income between tracts within the same community declines

# %%
# preparation for the next hipothesis
tracts_df['income_growth'] = tracts_df['income_2'] - tracts_df['income_1']
tracts_df['income_growth_p'] = (tracts_df['income_2'] - tracts_df['income_1']) / tracts_df['income_1']

# %%
club_conv_df = tracts_df.groupby(['city','algorithm_type','g_type','S_cons']).std().reset_index()[['city','algorithm_type','g_type','S_cons','income_1','income_2','income_growth','income_growth_p']]
club_conv_df['sigma_conv'] = club_conv_df['income_1'] - club_conv_df['income_2'] # difference of income std-s?
club_conv_df = club_conv_df.drop(columns = ['income_1' ,'income_2'])

# %%
hist(club_conv_df[club_conv_df['algorithm_type'] == 'ms']['sigma_conv'], color='blue',bins = 50, alpha=0.6, label='ms')
hist(club_conv_df[club_conv_df['algorithm_type'] == 'mgn']['sigma_conv'], color='yellow',bins = 50, alpha=0.6, label='mgn')
xlabel('sigma convergence of income')
ylabel('No. communities')
title('(Sigma) club convergence of income within clusters')
legend()
yscale('log')
grid()

# Most of the communities diverge
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# #### Hipothesis: Better communities are better convergence clubs

# %%
# egy S változót benne kell hagyni fentebb, nem droppolhatom ki mind TODO

mob_mgn_conv_df = pd.merge(mob_mgn_S_df, club_conv_df, on = ['city','S_cons'])
mob_ms_conv_df = pd.merge(mob_ms_S_df, club_conv_df, on = ['city','S_cons'])
fol_hh_mgn_conv_df = pd.merge(fol_hh_mgn_S_df, club_conv_df, on = ['city','S_cons'])
fol_hh_ms_conv_df = pd.merge(fol_hh_ms_S_df, club_conv_df, on = ['city','S_cons'])

# %% [raw]
# mobility - red
# follow_hh - green
# ms - dark
# mgn - lighter

# %%
# the larger the better
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['sigma_conv'], mob_mgn_conv_df['in'], color = 'Red', marker='o', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. intra community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['sigma_conv'], mob_ms_conv_df['in'], marker='o', color = 'DarkRed', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. intra community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['sigma_conv'], fol_hh_mgn_conv_df['in'], marker='o', color = 'Green', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. intra community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['sigma_conv'], fol_hh_ms_conv_df['in'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 14)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. intra community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['sigma_conv'], mob_mgn_conv_df['ctr'], marker='o',color = 'Red', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Contraction', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['sigma_conv'], mob_ms_conv_df['ctr'], marker='o', color = 'DarkRed',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Contraction', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['sigma_conv'], fol_hh_mgn_conv_df['ctr'], marker='o', color = 'Green',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Contraction', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['sigma_conv'], fol_hh_ms_conv_df['ctr'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Contraction', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['sigma_conv'], mob_mgn_conv_df['out'], marker='o',color = 'Red', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. inter community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['sigma_conv'], mob_ms_conv_df['out'], marker='o', color = 'DarkRed',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. inter community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['sigma_conv'], fol_hh_mgn_conv_df['out'], marker='o', color = 'Green',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. inter community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['sigma_conv'], fol_hh_ms_conv_df['out'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('No. inter community edges', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['sigma_conv'], mob_mgn_conv_df['expan'], marker='o',color = 'Red', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Expansion', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['sigma_conv'], mob_ms_conv_df['expan'], marker='o', color = 'DarkRed',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Expansion', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['sigma_conv'], fol_hh_mgn_conv_df['expan'], marker='o',color = 'Green', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Expansion', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['sigma_conv'], fol_hh_ms_conv_df['expan'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Expansion', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['sigma_conv'], mob_mgn_conv_df['cduc'], marker='o', color = 'Red',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['sigma_conv'], mob_ms_conv_df['cduc'], marker='o', color = 'DarkRed',alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['sigma_conv'], fol_hh_mgn_conv_df['cduc'], marker='o',color = 'Green', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['sigma_conv'], fol_hh_ms_conv_df['cduc'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income convergence and community quality', fontsize = 16)
plt.xlabel('Income sigma convergence 2012-2017', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %% [markdown]
# #### Hipothesis: The better the communities are the more similar their income growth

# %% [markdown]
# only for conductance to be faster

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['income_growth_p'], mob_mgn_conv_df['cduc'], marker='o', color = 'Red',alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (%) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['income_growth_p'], mob_ms_conv_df['cduc'], marker='o', color = 'DarkRed',alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (%) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['income_growth_p'], fol_hh_mgn_conv_df['cduc'], marker='o',color = 'Green', alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (%) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['income_growth_p'], fol_hh_ms_conv_df['cduc'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (%) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_mgn_conv_df['income_growth'], mob_mgn_conv_df['cduc'], marker='o', color = 'Red',alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (dollars) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(mob_ms_conv_df['income_growth'], mob_ms_conv_df['cduc'], marker='o', color = 'DarkRed',alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (dollars) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_mgn_conv_df['income_growth'], fol_hh_mgn_conv_df['cduc'], marker='o',color = 'Green', alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (dollars) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(7,5))
plt.scatter(fol_hh_ms_conv_df['income_growth'], fol_hh_ms_conv_df['cduc'], marker='o', color = 'DarkGreen', alpha=0.3)
plt.title('Income growth similarity and community quality', fontsize = 16)
plt.xlabel('Std. of income growth (dollars) of tracts in community', fontsize = 14)
plt.ylabel('Conductance', fontsize = 14)
plt.grid()

# %% [markdown]
# # THE END

# %%
clust_std_df = tracts_df.groupby([]) # KUKA
# Out:
# Index(['geoid', 'S_cons', 'city', 'algorithm_type', 'g_type', 'modularity',
#        'tracts_in_network', 'sum_tracts', 'county', 'nmi_to_counties',
#        'adj_nmi_to_counties', 'adj_rand_to_counties', 'state_1', 'county_1',
#        'tract_1', 'population_1', 'population_error_1', 'education_bachelor_1',
#        'education_bachelor_error_1', 'education_total_1',
#        'education_total_error_1', 'income_1', 'income_error_1', 'race_total_1',
#        'race_total_error_1', 'white_1', 'white_error_1', 'black_1',
#        'black_error_1', 'native_1', 'native_error_1', 'asian_1',
#        'asian_error_1', 'state_2', 'county_2', 'tract_2', 'population_2',
#        'population_error_2', 'education_bachelor_2',
#        'education_bachelor_error_2', 'education_total_2',
#        'education_total_error_2', 'income_2', 'income_error_2', 'race_total_2',
#        'race_total_error_2', 'white_2', 'white_error_2', 'black_2',
# ...

# %% [markdown]
# # Counties

# %%
set(counties.CBSAFP)
# Out:
# {'10020',
#  '10100',
#  '10140',
#  '10180',
#  '10220',
#  '10260',
#  '10300',
#  '10380',
#  '10420',
#  '10460',
#  '10500',
#  '10540',
#  '10580',
#  '10620',
#  '10660',
#  '10700',
#  '10740',
#  '10760',
#  '10780',
#  '10820',
#  '10860',
#  '10880',
#  '10900',
#  '10940',
#  '10980',
#  '11020',
#  '11060',
#  '11100',
#  '11140',
#  '11180',
#  '11220',
#  '11260',
#  '11300',
#  '11340',
#  '11380',
#  '11420',
#  '11460',
#  '11500',
#  '11540',
#  '11580',
#  '11620',
#  '11660',
#  '11700',
#  '11740',
#  '11780',
#  '11820',
#  '11860',
#  '11900',
#  '11940',
#  '11980',
#  '12020',
#  '12060',
#  '12100',
#  '12140',
#  '12180',
#  '12220',
#  '12260',
#  '12300',
#  '12380',
#  '12420',
#  '12460',
#  '12540',
#  '12580',
#  '12620',
#  '12660',
#  '12700',
#  '12740',
#  '12780',
#  '12820',
#  '12860',
#  '12900',
#  '12940',
#  '12980',
#  '13020',
#  '13060',
#  '13100',
#  '13140',
#  '13180',
#  '13220',
#  '13260',
#  '13300',
#  '13340',
#  '13380',
# ...

# %%
len(counties.GEOID.unique())
# Out:
# 3234

# %%
counties.nunique()
# Out:
# STATEFP       56
# COUNTYFP     329
# COUNTYNS    3234
# GEOID       3234
# NAME        1921
# NAMELSAD    1968
# LSAD          11
# CLASSFP        5
# MTFCC          1
# CSAFP        128
# CBSAFP       955
# METDIVFP      29
# FUNCSTAT       7
# ALAND       3234
# AWATER      3234
# INTPTLAT    3234
# INTPTLON    3234
# geometry    3234
# dtype: int64

# %% [markdown]
# ## To be deleted

# %%
# unique values in the network counted by side of edge

mob_u_h = mobility.tract_home.tolist()
mob_u_w = mobility.tract_work.tolist()
u_geoid_mob = set([*mob_u_h,*mob_u_w])
cbsacode['in_mob'] = cbsacode.geoid.isin(u_geoid_mob).astype(int)

fol_u_h = follow_hh.tract_home.tolist()
fol_u_h1 = follow_hh.tract_home_1.tolist()
u_geoid_fol = set([*fol_u_h,*fol_u_h1])
cbsacode['in_fol'] = cbsacode.geoid.isin(u_geoid_fol).astype(int)

# %%
netw_count = cbsacode.groupby('cbsacode')[['in_mob','in_fol']].sum()

# %%
city_df = pd.merge(tract_sum, netw_count, left_index=True, right_index=True)

# %%
tract = mobility.groupby('tract_home')[['cnt']].sum()

# %%
tract.head()
# Out:
#                     cnt
# tract_home
# 14000US01007010001    9
# 14000US01007010002   14
# 14000US01007010003   10
# 14000US01007010004   22
# 14000US01009050101   21
# ...                 ...
# 14000US55133204301    7
# 14000US55133204302    9
# 14000US55133204400    7
# 14000US55133204501    2
# 14000US55133204502   17
#
# [38343 rows x 1 columns]

# %% [raw]
# # RÉGI
# # filter
# mobility = mobility[mobility["cbsacode"] == city_code]
# follow_hh = follow_hh[follow_hh["cbsacode"] == city_code]
#
# # create graphs
# # create empty graphs
# g_mob = nx.Graph() # mobility graph - weights are counts
# ## g_mob_lw = nx.Graph() # log edge weights - new_weight=log(1+weight)
# ## g_mob_Nw = nx.Graph() # with NO WEIGHTS
#
# g_fol_hh = nx.Graph() # follow home-home graph - weights are counts
# ## g_fol_hh_lw = nx.Graph() # graphs with log edge weights - new_weight=log(1+weight)
# ## g_fol_hh_Nw = nx.Graph() # graphs with NO WEIGHTS
#
#
# # fill in the networks with data
# mobility['w_edges'] = list(zip(mobility.tract_home,mobility.tract_work,mobility.cnt))
# g_mob.add_weighted_edges_from(mobility["w_edges"], weight='cnt')
#
# follow_hh['w_edges'] = list(zip(follow_hh.tract_home,follow_hh.tract_home_1,follow_hh.cnt))
# g_fol_hh.add_weighted_edges_from(follow_hh["w_edges"], weight='cnt')
#
#
# ## graph with log weights
# ## mobility['cnt_2']=np.log(1+mobility['cnt'])
# ## mobility['w_edges_2']=list(zip(mobility.tract_home,mobility.tract_work,mobility.cnt_2))
# ## g_mob_lw.add_weighted_edges_from(mobility["w_edges_2"], weight='cnt_2')
#
# ## follow_hh['cnt_2']=np.log(1+follow_hh['cnt'])
# ## follow_hh['w_edges_2']=list(zip(follow_hh.tract_home,follow_hh.tract_home_1,follow_hh.cnt_2))
# ## g_fol_hh_lw.add_weighted_edges_from(follow_hh["w_edges_2"], weight='cnt_2')
#
#
# ## graph with NO WEIGHTS
# ## mobility['edges'] = list(zip(mobility.tract_home,mobility.tract_work))
# ## g_mob_Nw.add_edges_from(mobility['edges'])
#
# ## follow_hh['edges'] = list(zip(follow_hh.tract_home,follow_hh.tract_home_1))
# ## g_fol_hh_Nw.add_edges_from(follow_hh['edges'])
#
#
# ## KERDES SELF LOOPS???? - EZ NEM BIZTOS, HOGY MŰKÖDIK!!!!!!
# # remove self loops
# g_mob.remove_edges_from(nx.selfloop_edges(g_mob))
# ## g_mob_lw.remove_edges_from(nx.selfloop_edges(g_mob_lw))
# ## g_mob_Nw.remove_edges_from(nx.selfloop_edges(g_mob_Nw))
#
# g_fol_hh.remove_edges_from(nx.selfloop_edges(g_fol_hh))
# ## g_fol_hh_lw.remove_edges_from(nx.selfloop_edges(g_fol_hh_lw))
# ## g_fol_hh_Nw.remove_edges_from(nx.selfloop_edges(g_fol_hh_Nw))

# %% [raw]
# # RÉGI
#
# coords = np.array([tract_center_dict[n] for n in G.nodes()])
#
# d = pdist(coords)
# D = squareform(pdist(coords))
#
# max_dist = np.amax(D)
#
# # adjacency matrix
# A = nx.adjacency_matrix(G)
#
# #### KERDES -  jo, ha az importance mindig a mobilityből van számolva??????
# # importance - number of users
# tract_outdeg_mob = mobility.groupby('tract_home')[['cnt']].sum()
# N = np.matrix([tract_outdeg_mob.loc[k].iloc[0] for k in G.nodes()]).T
#
# # binsize
# b = max_dist/99 # number of bins = 100

# %%
# %%writefile toto.m
#
# function [a, b] = toto(c);
#     a = c;
#     b = c + 1;
# end

# %%
a,b = octave.toto(3, nout=2)
